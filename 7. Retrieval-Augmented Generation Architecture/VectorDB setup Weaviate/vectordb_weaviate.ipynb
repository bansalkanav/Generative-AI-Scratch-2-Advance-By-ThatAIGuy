# %% [markdown]
# ## **Installation**

# %%
# ! pip install weaviate-client

# %%
! pip show weaviate-client
# Out:
# Name: weaviate-client
# Version: 4.20.1
# Summary: A python native Weaviate client
# Home-page: https://github.com/weaviate/weaviate-python-client
# Author: Weaviate
# Author-email: hello@weaviate.io,
# License: BSD 3-clause
# Location: /Users/kanavbansal/Developer/.env_jupyter/lib/python3.13/site-packages
# Requires: authlib, deprecation, grpcio, httpx, protobuf, pydantic, validators
# Required-by: langchain-weaviate

# %%
from weaviate.classes.config import Configure, Property, Datatype

# %%
import weaviate

client = weaviate.connect_to_local()

print(client.is_ready())
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/weaviate/connect/v4.py:421, in _ConnectionBase._open_connections_rest(self, auth_client_secret, colour)
#     420 try:
# --> 421     response = client.get(oidc_url, timeout=self.timeout_config.init)
#     422 except Exception as e:
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpx/_client.py:1053, in Client.get(self, url, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1048 """
#    1049 Send a `GET` request.
#    1050
#    1051 **Parameters**: See `httpx.request`.
#    1052 """
# -> 1053 return self.request(
#    1054     "GET",
#    1055     url,
#    1056     params=params,
#    1057     headers=headers,
#    1058     cookies=cookies,
#    1059     auth=auth,
#    1060     follow_redirects=follow_redirects,
#    1061     timeout=timeout,
#    1062     extensions=extensions,
#    1063 )
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# WeaviateConnectionError                   Traceback (most recent call last)
# Cell In[4], line 3
#       1 import weaviate
# ----> 3 client = weaviate.connect_to_local()
#       5 print(client.is_ready())
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/weaviate/connect/helpers.py:193, in connect_to_local(host, port, grpc_port, headers, additional_config, skip_init_checks, auth_credentials)
#     142 def connect_to_local(
#     143     host: str = "localhost",
#     144     port: int = 8080,
#    (...)    149     auth_credentials: Union[str, AuthCredentials, None] = None,
#     150 ) -> WeaviateClient:
#     151     """Connect to a local Weaviate instance deployed using Docker compose with standard port configurations.
#     152
#     153     This method handles automatically connecting to Weaviate but not automatically closing the connection. Once you are done with the client
#    (...)    191         >>> # The connection is automatically closed when the context is exited.
#     192     """
# --> 193     return __connect(
#     194         WeaviateClient(
#     195             connection_params=ConnectionParams(
#     196                 http=ProtocolParams(host=host, port=port, secure=False),
#     197                 grpc=ProtocolParams(host=host, port=grpc_port, secure=False),
#     198             ),
#     199             additional_headers=headers,
#     200             additional_config=additional_config,
#     201             skip_init_checks=skip_init_checks,
#     202             auth_client_secret=__parse_auth_credentials(auth_credentials),
#     203         )
#     204     )
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/weaviate/connect/helpers.py:371, in __connect(client)
#     369 except Exception as e:
#     370     client.close()
# --> 371     raise e
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/weaviate/connect/helpers.py:367, in __connect(client)
#     365 def __connect(client: WeaviateClient) -> WeaviateClient:
#     366     try:
# --> 367         client.connect()
#     368         return client
#     369     except Exception as e:
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/weaviate/client_executor.py:152, in _WeaviateClientExecutor.connect(self)
#     140 def connect(self) -> executor.Result[None]:
#     141     """Connect to the Weaviate instance performing all the necessary checks.
#     142
#     143     If you have specified `skip_init_checks` in the constructor then this method will not perform any runtime checks
#    (...)    150         weaviate.exceptions.UnexpectedStatusCodeError: If weaviate reports a none OK status.
#     151     """
# --> 152     return executor.execute(
#     153         response_callback=lambda _: None,
#     154         method=self._connection.connect,
#     155     )
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/weaviate/connect/executor.py:99, in execute(method, response_callback, exception_callback, *args, **kwargs)
#      97     return resp_call
#      98 except Exception as e:
# ---> 99     return cast(T, exception_callback(e))
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/weaviate/connect/executor.py:38, in raise_exception(e)
#      37 def raise_exception(e: Exception) -> Any:
# ---> 38     raise e
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/weaviate/connect/executor.py:80, in execute(method, response_callback, exception_callback, *args, **kwargs)
#      71 def execute(
#      72     method: SyncOrAsyncMethod[P, R],
#      73     response_callback: SyncOrAsyncCallback[R, T, A],
#    (...)     77 ) -> Union[T, Awaitable[T], Awaitable[A]]:
#      78     # wrap method call in try-except to catch exceptions for sync method
#      79     try:
# ---> 80         call = method(*args, **kwargs)
#      81         if isinstance(call, Awaitable):
#      83             async def _execute() -> T:
#      84                 # wrap await in try-except to catch exceptions for async method
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/weaviate/connect/v4.py:902, in ConnectionSync.connect(self, force)
#     899 if self._connected and not force:
#     900     return None
# --> 902 self._open_connections_rest(self._auth, "sync")
#     904 # need this to get the version of weaviate for version checks and proper GRPC configuration
#     905 try:
#
# File ~/Developer/.env_jupyter/lib/python3.13/site-packages/weaviate/connect/v4.py:423, in _ConnectionBase._open_connections_rest(self, auth_client_secret, colour)
#     421         response = client.get(oidc_url, timeout=self.timeout_config.init)
#     422     except Exception as e:
# --> 423         raise WeaviateConnectionError(
#     424             f"Error: {e}. \nIs Weaviate running and reachable at {self.url}?"
#     425         )
#     426 res = self.__process_oidc_response(response, auth_client_secret, oidc_url, colour)
#     427 assert not isinstance(res, Awaitable)
#
# WeaviateConnectionError: Connection to Weaviate failed. Details: Error: [Errno 61] Connection refused.
# Is Weaviate running and reachable at http://localhost:8080?
