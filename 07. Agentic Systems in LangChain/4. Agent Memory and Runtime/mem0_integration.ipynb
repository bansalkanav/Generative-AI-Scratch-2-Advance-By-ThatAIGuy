# %% [markdown]
# ## **TODO:**
#
# Mem0 Memory Integration:
# - Long-term Memory: https://mem0.ai/blog/long-term-memory-ai-agents
# - LangChain Mem0 Integration: https://docs.mem0.ai/integrations/langchain#create-chat-turn-function
# - LangChain Tool Mem0 Integration: https://docs.mem0.ai/integrations/langchain-tools
# - LangGraph Mem0 Integration: https://docs.mem0.ai/integrations/langgraph#create-chatbot-function
