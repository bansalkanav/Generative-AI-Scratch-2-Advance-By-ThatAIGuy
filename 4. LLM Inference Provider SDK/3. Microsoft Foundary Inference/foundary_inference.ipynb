# %%
from langchain_openai import AzureChatOpenAI

llm = AzureChatOpenAI(
    openai_api_key="",
    api_version="",
    azure_endpoint="",
    deployment_name="",
    temperature=0
)

# %% [markdown]
# - https://learn.microsoft.com/en-us/azure/foundry-classic/how-to/develop/langchain
#
#
#
# - https://www.youtube.com/watch?v=Nu14lrjDDTM&list=PLLPrkPALrjwu6iRXduFAHWWlMvh1HJYFK&index=2
#
#
#
# Use code interpreter sessions in LangChain with Azure Container Apps
# - https://learn.microsoft.com/en-us/azure/container-apps/sessions-tutorial-langchain
