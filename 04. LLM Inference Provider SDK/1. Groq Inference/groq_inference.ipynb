# %% [markdown]
# # **Inference Providers**
#
# ## **What's Covered?**
# 1. What are Infererence Providers?
# 2. Example Usage - Inferencing Meta Llama Model with Groq
# 3. Example Usage - Inferencing OpenAI GPT OSS Model with Groq

# %% [markdown]
# ## **Inference Providers**
#
# ### **What are Infererence Providers?**
# Inference Providers are AI-focused technology companies, specifically falling into the categories of **inference-as-a-service** providers. They allow developers to run, host, or deploy AI models without managing their own heavy infrastructure. Few popular inference providers are:
# - Groq
# - Replicate
# - Novita AI
# - Sambanova
# - etc...

# %% [markdown]
# ### **Example Usage - Inferencing Meta Llama Model with Groq**

# %%
# !pip install groq

# %%
from groq import Groq

client = Groq(api_key="ENTER_YOUR_API_KEY")

completion = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
      {
        "role": "user",
        "content": "provide 3 generative ai mcq questions with answers?"
      }
    ],
    temperature=1,
    max_completion_tokens=500,
    top_p=1,
    stream=True,
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# Here are three multiple-choice questions (MCQs) on Generative AI, along with answers:
#
# **Question 1:** What is the primary function of a Generative Adversarial Network (GAN)?
#
# A) To classify images into predefined categories
# B) To generate new, synthetic data that resembles real-world data
# C) To compress existing data into a smaller file size
# D) To segment objects from backgrounds in images
#
# **Answer:** B) To generate new, synthetic data that resembles real-world data
#
# **Question 2:** Which of the following statements is true about Generative Pre-trained Transformers (GPTs)?
#
# A) They use a pre-training stage where they are fine-tuned for a particular task
# B) They use a single neural network layer to process sequential data
# C) They use an encoder-decoder architecture with a self-supervised learning approach
# D) They do not use any additional pre-training steps before fine-tuning for specific tasks
#
# **Answer:** C) They use an encoder-decoder architecture with a self-supervised learning approach
#
# **Question 3:** What is the term for the process by which Generative AI models are trained on a dataset and then asked to generate new content that is similar to the training data?
#
# A) Inference
# B) Fine-tuning
# C) Generation
# D) Imprinting
#
# **Answer:** A) Inference (Note: Although the term 'inference' is commonly used to describe the process of applying a trained model to new data, in the context of Generative AI, 'inference' often specifically refers to the application of a trained model to generate new content rather than making class predictions or other inferences.)

# %%
from groq import Groq

client = Groq(api_key="ENTER_YOUR_API_KEY")
completion = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
      {
        "role": "user",
        "content": "provide 3 generative ai mcq questions with answers?"
      }
    ],
    temperature=1,
    max_completion_tokens=8192,
    top_p=1,
    reasoning_effort="medium",
    stream=True,
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# **Generative‑AI MCQs**
#
# ---
#
# **Q1. Which of the following architectures is primarily responsible for the recent surge in large‑scale language generation models such as GPT‑4 and Claude?**
#
# A) Recurrent Neural Network (RNN)
# B) Convolutional Neural Network (CNN)
# C) Transformer with self‑attention
# D) Long‑Short‑Term Memory (LSTM)
#
# **Answer:** C) Transformer with self‑attention
#
# ---
#
# **Q2. In diffusion‑based generative models, what is the main purpose of the “denoising” step during inference?**
#
# A) To add random noise to the latent vector
# B) To progressively remove noise and refine the sample
# C) To enforce sparsity in the output
# D) To increase the dimensionality of the latent space
#
# **Answer:** B) To progressively remove noise and refine the sample
#
# ---
#
# **Q3. Which metric is most commonly used to evaluate the quality of machine‑generated text against a human‑written reference?**
#
# A) Mean Squared Error (MSE)
# B) BLEU (Bilingual Evaluation Understudy)
# C) Signal‑to‑Noise Ratio (SNR)
# D) Cosine Similarity
#
# **Answer:** B) BLEU (Bilingual Evaluation Understudy)**
